# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
documentA='in sooth I know not why I am so sad it wearies me you say it wearies you but how I caught it found it or came by it what stuff tis made of whereof it is born I am to learn and such a want wit sadness makes of me that I have much ado to know myself'
documentB='your mind is tossing on the ocean there where your argosies with portly sail like signors and rich burghers on the flood or as it were the pageants of the sea do overpeer the petty traffickers that curtsy to them do them reverence as they fly by them with their woven wings'

# %%
bagOfWordsA=documentA.split(' ')
bagOfWordsB=documentB.split(' ')

# %%
bagOfWordsA
# Out:
# ['in',
#  'sooth',
#  'I',
#  'know',
#  'not',
#  'why',
#  'I',
#  'am',
#  'so',
#  'sad',
#  'it',
#  'wearies',
#  'me',
#  'you',
#  'say',
#  'it',
#  'wearies',
#  'you',
#  'but',
#  'how',
#  'I',
#  'caught',
#  'it',
#  'found',
#  'it',
#  'or',
#  'came',
#  'by',
#  'it',
#  'what',
#  'stuff',
#  'tis',
#  'made',
#  'of',
#  'whereof',
#  'it',
#  'is',
#  'born',
#  'I',
#  'am',
#  'to',
#  'learn',
#  'and',
#  'such',
#  'a',
#  'want',
#  'wit',
#  'sadness',
#  'makes',
#  'of',
#  'me',
#  'that',
#  'I',
#  'have',
#  'much',
#  'ado',
#  'to',
#  'know',
#  'myself']

# %%
bagOfWordsB
# Out:
# ['your',
#  'mind',
#  'is',
#  'tossing',
#  'on',
#  'the',
#  'ocean',
#  'there',
#  'where',
#  'your',
#  'argosies',
#  'with',
#  'portly',
#  'sail',
#  'like',
#  'signors',
#  'and',
#  'rich',
#  'burghers',
#  'on',
#  'the',
#  'flood',
#  'or',
#  'as',
#  'it',
#  'were',
#  'the',
#  'pageants',
#  'of',
#  'the',
#  'sea',
#  'do',
#  'overpeer',
#  'the',
#  'petty',
#  'traffickers',
#  'that',
#  'curtsy',
#  'to',
#  'them',
#  'do',
#  'them',
#  'reverence',
#  'as',
#  'they',
#  'fly',
#  'by',
#  'them',
#  'with',
#  'their',
#  'woven',
#  'wings']

# %%
uniqueWords=set(bagOfWordsA).union(set(bagOfWordsB))
uniqueWords
# Out:
# {'I',
#  'a',
#  'ado',
#  'am',
#  'and',
#  'argosies',
#  'as',
#  'born',
#  'burghers',
#  'but',
#  'by',
#  'came',
#  'caught',
#  'curtsy',
#  'do',
#  'flood',
#  'fly',
#  'found',
#  'have',
#  'how',
#  'in',
#  'is',
#  'it',
#  'know',
#  'learn',
#  'like',
#  'made',
#  'makes',
#  'me',
#  'mind',
#  'much',
#  'myself',
#  'not',
#  'ocean',
#  'of',
#  'on',
#  'or',
#  'overpeer',
#  'pageants',
#  'petty',
#  'portly',
#  'reverence',
#  'rich',
#  'sad',
#  'sadness',
#  'sail',
#  'say',
#  'sea',
#  'signors',
#  'so',
#  'sooth',
#  'stuff',
#  'such',
#  'that',
#  'the',
#  'their',
#  'them',
#  'there',
#  'they',
#  'tis',
#  'to',
#  'tossing',
#  'traffickers',
#  'want',
#  'wearies',
#  'were',
#  'what',
#  'where',
#  'whereof',
#  'why',
#  'wings',
#  'wit',
#  'with',
#  'woven',
#  'you',
#  'your'}

# %%
#from nltk.corpus import stopwords
#stop_words=set(stopwords.words('english'))
#stop_words

# %%
#filtered=[]
#for w in uniqueWords:
#    if w not in stop_words:
#        filtered.append(w)

# %%
#filtered

# %%
numOfWordsA=dict.fromkeys(uniqueWords,0)
for word in bagOfWordsA:
    numOfWordsA[word]+=1

numOfWordsB=dict.fromkeys(uniqueWords,0)
for word in bagOfWordsB:
    numOfWordsB[word]+=1

# %%
numOfWordsA
# Out:
# {'made': 1,
#  'wearies': 2,
#  'curtsy': 0,
#  'petty': 0,
#  'want': 1,
#  'burghers': 0,
#  'flood': 0,
#  'you': 2,
#  'ado': 1,
#  'is': 1,
#  'in': 1,
#  'have': 1,
#  'found': 1,
#  'of': 2,
#  'born': 1,
#  'pageants': 0,
#  'them': 0,
#  'were': 0,
#  'that': 1,
#  'fly': 0,
#  'not': 1,
#  'ocean': 0,
#  'such': 1,
#  'portly': 0,
#  'their': 0,
#  'what': 1,
#  'or': 1,
#  'with': 0,
#  'mind': 0,
#  'by': 1,
#  'like': 0,
#  'caught': 1,
#  'tis': 1,
#  'so': 1,
#  'tossing': 0,
#  'overpeer': 0,
#  'came': 1,
#  'on': 0,
#  'they': 0,
#  'stuff': 1,
#  'how': 1,
#  'am': 2,
#  'know': 2,
#  'why': 1,
#  'reverence': 0,
#  'signors': 0,
#  'wings': 0,
#  'a': 1,
#  'me': 2,
#  'sadness': 1,
#  'where': 0,
#  'and': 1,
#  'your': 0,
#  'whereof': 1,
#  'the': 0,
#  'as': 0,
#  'sad': 1,
#  'but': 1,
#  'much': 1,
#  'sail': 0,
#  'say': 1,
#  'rich': 0,
#  'myself': 1,
#  'there': 0,
#  'it': 6,
#  'traffickers': 0,
#  'to': 2,
#  'learn': 1,
#  'sea': 0,
#  'woven': 0,
#  'argosies': 0,
#  'do': 0,
#  'wit': 1,
#  'makes': 1,
#  'I': 5,
#  'sooth': 1}

# %%
numOfWordsB
# Out:
# {'made': 0,
#  'wearies': 0,
#  'curtsy': 1,
#  'petty': 1,
#  'want': 0,
#  'burghers': 1,
#  'flood': 1,
#  'you': 0,
#  'ado': 0,
#  'is': 1,
#  'in': 0,
#  'have': 0,
#  'found': 0,
#  'of': 1,
#  'born': 0,
#  'pageants': 1,
#  'them': 3,
#  'were': 1,
#  'that': 1,
#  'fly': 1,
#  'not': 0,
#  'ocean': 1,
#  'such': 0,
#  'portly': 1,
#  'their': 1,
#  'what': 0,
#  'or': 1,
#  'with': 2,
#  'mind': 1,
#  'by': 1,
#  'like': 1,
#  'caught': 0,
#  'tis': 0,
#  'so': 0,
#  'tossing': 1,
#  'overpeer': 1,
#  'came': 0,
#  'on': 2,
#  'they': 1,
#  'stuff': 0,
#  'how': 0,
#  'am': 0,
#  'know': 0,
#  'why': 0,
#  'reverence': 1,
#  'signors': 1,
#  'wings': 1,
#  'a': 0,
#  'me': 0,
#  'sadness': 0,
#  'where': 1,
#  'and': 1,
#  'your': 2,
#  'whereof': 0,
#  'the': 5,
#  'as': 2,
#  'sad': 0,
#  'but': 0,
#  'much': 0,
#  'sail': 1,
#  'say': 0,
#  'rich': 1,
#  'myself': 0,
#  'there': 1,
#  'it': 1,
#  'traffickers': 1,
#  'to': 1,
#  'learn': 0,
#  'sea': 1,
#  'woven': 1,
#  'argosies': 1,
#  'do': 2,
#  'wit': 0,
#  'makes': 0,
#  'I': 0,
#  'sooth': 0}

# %%
def computeTF(wordDict, bagOfWords):
    tfDict = {} #dictionary
    bagOfWordsCount = len(bagOfWords)
    for word, count in wordDict.items():
        tfDict[word] = count / float(bagOfWordsCount)
    return tfDict
#funtion to compute tf

# %%
tfA=computeTF(numOfWordsA,bagOfWordsA)

# %%
tfA
# Out:
# {'made': 0.01694915254237288,
#  'wearies': 0.03389830508474576,
#  'curtsy': 0.0,
#  'petty': 0.0,
#  'want': 0.01694915254237288,
#  'burghers': 0.0,
#  'flood': 0.0,
#  'you': 0.03389830508474576,
#  'ado': 0.01694915254237288,
#  'is': 0.01694915254237288,
#  'in': 0.01694915254237288,
#  'have': 0.01694915254237288,
#  'found': 0.01694915254237288,
#  'of': 0.03389830508474576,
#  'born': 0.01694915254237288,
#  'pageants': 0.0,
#  'them': 0.0,
#  'were': 0.0,
#  'that': 0.01694915254237288,
#  'fly': 0.0,
#  'not': 0.01694915254237288,
#  'ocean': 0.0,
#  'such': 0.01694915254237288,
#  'portly': 0.0,
#  'their': 0.0,
#  'what': 0.01694915254237288,
#  'or': 0.01694915254237288,
#  'with': 0.0,
#  'mind': 0.0,
#  'by': 0.01694915254237288,
#  'like': 0.0,
#  'caught': 0.01694915254237288,
#  'tis': 0.01694915254237288,
#  'so': 0.01694915254237288,
#  'tossing': 0.0,
#  'overpeer': 0.0,
#  'came': 0.01694915254237288,
#  'on': 0.0,
#  'they': 0.0,
#  'stuff': 0.01694915254237288,
#  'how': 0.01694915254237288,
#  'am': 0.03389830508474576,
#  'know': 0.03389830508474576,
#  'why': 0.01694915254237288,
#  'reverence': 0.0,
#  'signors': 0.0,
#  'wings': 0.0,
#  'a': 0.01694915254237288,
#  'me': 0.03389830508474576,
#  'sadness': 0.01694915254237288,
#  'where': 0.0,
#  'and': 0.01694915254237288,
#  'your': 0.0,
#  'whereof': 0.01694915254237288,
#  'the': 0.0,
#  'as': 0.0,
#  'sad': 0.01694915254237288,
#  'but': 0.01694915254237288,
#  'much': 0.01694915254237288,
#  'sail': 0.0,
#  'say': 0.01694915254237288,
#  'rich': 0.0,
#  'myself': 0.01694915254237288,
#  'there': 0.0,
#  'it': 0.1016949152542373,
#  'traffickers': 0.0,
#  'to': 0.03389830508474576,
#  'learn': 0.01694915254237288,
#  'sea': 0.0,
#  'woven': 0.0,
#  'argosies': 0.0,
#  'do': 0.0,
#  'wit': 0.01694915254237288,
#  'makes': 0.01694915254237288,
#  'I': 0.0847457627118644,
#  'sooth': 0.01694915254237288}

# %%
tfB=computeTF(numOfWordsB,bagOfWordsB)
tfB
# Out:
# {'made': 0.0,
#  'wearies': 0.0,
#  'curtsy': 0.019230769230769232,
#  'petty': 0.019230769230769232,
#  'want': 0.0,
#  'burghers': 0.019230769230769232,
#  'flood': 0.019230769230769232,
#  'you': 0.0,
#  'ado': 0.0,
#  'is': 0.019230769230769232,
#  'in': 0.0,
#  'have': 0.0,
#  'found': 0.0,
#  'of': 0.019230769230769232,
#  'born': 0.0,
#  'pageants': 0.019230769230769232,
#  'them': 0.057692307692307696,
#  'were': 0.019230769230769232,
#  'that': 0.019230769230769232,
#  'fly': 0.019230769230769232,
#  'not': 0.0,
#  'ocean': 0.019230769230769232,
#  'such': 0.0,
#  'portly': 0.019230769230769232,
#  'their': 0.019230769230769232,
#  'what': 0.0,
#  'or': 0.019230769230769232,
#  'with': 0.038461538461538464,
#  'mind': 0.019230769230769232,
#  'by': 0.019230769230769232,
#  'like': 0.019230769230769232,
#  'caught': 0.0,
#  'tis': 0.0,
#  'so': 0.0,
#  'tossing': 0.019230769230769232,
#  'overpeer': 0.019230769230769232,
#  'came': 0.0,
#  'on': 0.038461538461538464,
#  'they': 0.019230769230769232,
#  'stuff': 0.0,
#  'how': 0.0,
#  'am': 0.0,
#  'know': 0.0,
#  'why': 0.0,
#  'reverence': 0.019230769230769232,
#  'signors': 0.019230769230769232,
#  'wings': 0.019230769230769232,
#  'a': 0.0,
#  'me': 0.0,
#  'sadness': 0.0,
#  'where': 0.019230769230769232,
#  'and': 0.019230769230769232,
#  'your': 0.038461538461538464,
#  'whereof': 0.0,
#  'the': 0.09615384615384616,
#  'as': 0.038461538461538464,
#  'sad': 0.0,
#  'but': 0.0,
#  'much': 0.0,
#  'sail': 0.019230769230769232,
#  'say': 0.0,
#  'rich': 0.019230769230769232,
#  'myself': 0.0,
#  'there': 0.019230769230769232,
#  'it': 0.019230769230769232,
#  'traffickers': 0.019230769230769232,
#  'to': 0.019230769230769232,
#  'learn': 0.0,
#  'sea': 0.019230769230769232,
#  'woven': 0.019230769230769232,
#  'argosies': 0.019230769230769232,
#  'do': 0.038461538461538464,
#  'wit': 0.0,
#  'makes': 0.0,
#  'I': 0.0,
#  'sooth': 0.0}

# %%
def computeIDF(documents):
    import math
    N = len(documents)
    
    idfDict = dict.fromkeys(documents[0].keys(), 0)
    for document in documents:
        for word, val in document.items():
            if val > 0:
                idfDict[word] += 1
    
    for word, val in idfDict.items():
        idfDict[word] = math.log(N / float(val))
    return idfDict

# %%
idfs = computeIDF([numOfWordsA, numOfWordsB])

# %%
idfs
# Out:
# {'made': 0.6931471805599453,
#  'wearies': 0.6931471805599453,
#  'curtsy': 0.6931471805599453,
#  'petty': 0.6931471805599453,
#  'want': 0.6931471805599453,
#  'burghers': 0.6931471805599453,
#  'flood': 0.6931471805599453,
#  'you': 0.6931471805599453,
#  'ado': 0.6931471805599453,
#  'is': 0.0,
#  'in': 0.6931471805599453,
#  'have': 0.6931471805599453,
#  'found': 0.6931471805599453,
#  'of': 0.0,
#  'born': 0.6931471805599453,
#  'pageants': 0.6931471805599453,
#  'them': 0.6931471805599453,
#  'were': 0.6931471805599453,
#  'that': 0.0,
#  'fly': 0.6931471805599453,
#  'not': 0.6931471805599453,
#  'ocean': 0.6931471805599453,
#  'such': 0.6931471805599453,
#  'portly': 0.6931471805599453,
#  'their': 0.6931471805599453,
#  'what': 0.6931471805599453,
#  'or': 0.0,
#  'with': 0.6931471805599453,
#  'mind': 0.6931471805599453,
#  'by': 0.0,
#  'like': 0.6931471805599453,
#  'caught': 0.6931471805599453,
#  'tis': 0.6931471805599453,
#  'so': 0.6931471805599453,
#  'tossing': 0.6931471805599453,
#  'overpeer': 0.6931471805599453,
#  'came': 0.6931471805599453,
#  'on': 0.6931471805599453,
#  'they': 0.6931471805599453,
#  'stuff': 0.6931471805599453,
#  'how': 0.6931471805599453,
#  'am': 0.6931471805599453,
#  'know': 0.6931471805599453,
#  'why': 0.6931471805599453,
#  'reverence': 0.6931471805599453,
#  'signors': 0.6931471805599453,
#  'wings': 0.6931471805599453,
#  'a': 0.6931471805599453,
#  'me': 0.6931471805599453,
#  'sadness': 0.6931471805599453,
#  'where': 0.6931471805599453,
#  'and': 0.0,
#  'your': 0.6931471805599453,
#  'whereof': 0.6931471805599453,
#  'the': 0.6931471805599453,
#  'as': 0.6931471805599453,
#  'sad': 0.6931471805599453,
#  'but': 0.6931471805599453,
#  'much': 0.6931471805599453,
#  'sail': 0.6931471805599453,
#  'say': 0.6931471805599453,
#  'rich': 0.6931471805599453,
#  'myself': 0.6931471805599453,
#  'there': 0.6931471805599453,
#  'it': 0.0,
#  'traffickers': 0.6931471805599453,
#  'to': 0.0,
#  'learn': 0.6931471805599453,
#  'sea': 0.6931471805599453,
#  'woven': 0.6931471805599453,
#  'argosies': 0.6931471805599453,
#  'do': 0.6931471805599453,
#  'wit': 0.6931471805599453,
#  'makes': 0.6931471805599453,
#  'I': 0.6931471805599453,
#  'sooth': 0.6931471805599453}

# %%
def computeTFIDF(tfBagOfWords, idfs):
    tfidf = {}
    for word, val in tfBagOfWords.items():
        tfidf[word] = val * idfs[word]
    return tfidf

# %%
tfidfA = computeTFIDF(tfA, idfs)
tfidfB = computeTFIDF(tfB, idfs)
df = pd.DataFrame([tfidfA, tfidfB])

# %%
df
# Out:
#        made   wearies   curtsy    petty      want  burghers    flood  \
# 0  0.011748  0.023497  0.00000  0.00000  0.011748   0.00000  0.00000
# 1  0.000000  0.000000  0.01333  0.01333  0.000000   0.01333  0.01333
#
#         you       ado   is  ...   to     learn      sea    woven  argosies  \
# 0  0.023497  0.011748  0.0  ...  0.0  0.011748  0.00000  0.00000   0.00000
# 1  0.000000  0.000000  0.0  ...  0.0  0.000000  0.01333  0.01333   0.01333
#
#         do       wit     makes         I     sooth
# 0  0.00000  0.011748  0.011748  0.058741  0.011748
# 1  0.02666  0.000000  0.000000  0.000000  0.000000
#
# [2 rows x 76 columns]

# %%
#https://towardsdatascience.com/natural-language-processing-feature-engineering-using-tf-idf-e8b9d00e7e76
#https://towardsdatascience.com/tf-term-frequency-idf-inverse-document-frequency-from-scratch-in-python-6c2b61b78558
